# %% [markdown]
# <a href="https://colab.research.google.com/github/motathais/Site---Projeto-Interdisciplinar-1-Semestre-/blob/main/ExemploEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.6.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.4.2)

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_Banco_de_Dados_NoSQL/main/material%20de%20apoio/base%20de%20dados/Coordenadas%20csv.csv "

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente = MongoClient("mongodb+srv://thaismferreira42:3RzAcSqP8gCEB7YE@clusterestadios.kraihd5.mongodb.net/?retryWrites=true&w=majority")

# %%
db = cliente.get_database('futebol')

# %%
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('654fe3fe6b7ce4b2632ee402'), ObjectId('654fe3fe6b7ce4b2632ee403'), ObjectId('654fe3fe6b7ce4b2632ee404'), ObjectId('654fe3fe6b7ce4b2632ee405'), ObjectId('654fe3fe6b7ce4b2632ee406'), ObjectId('654fe3fe6b7ce4b2632ee407'), ObjectId('654fe3fe6b7ce4b2632ee408'), ObjectId('654fe3fe6b7ce4b2632ee409'), ObjectId('654fe3fe6b7ce4b2632ee40a'), ObjectId('654fe3fe6b7ce4b2632ee40b'), ObjectId('654fe3fe6b7ce4b2632ee40c'), ObjectId('654fe3fe6b7ce4b2632ee40d'), ObjectId('654fe3fe6b7ce4b2632ee40e'), ObjectId('654fe3fe6b7ce4b2632ee40f'), ObjectId('654fe3fe6b7ce4b2632ee410'), ObjectId('654fe3fe6b7ce4b2632ee411'), ObjectId('654fe3fe6b7ce4b2632ee412'), ObjectId('654fe3fe6b7ce4b2632ee413'), ObjectId('654fe3fe6b7ce4b2632ee414'), ObjectId('654fe3fe6b7ce4b2632ee415')], acknowledged=True)

# %%
estadios =db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['ac-6dttnn4-shard-00-02.kraihd5.mongodb.net:27017', 'ac-6dttnn4-shard-00-00.kraihd5.mongodb.net:27017', 'ac-6dttnn4-shard-00-01.kraihd5.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-guw1ug-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('654fbdb371ce47d4c8c66639'),
#   'name': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.571243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3ed'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3ee'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3ef'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f0'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f1'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f2'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f3'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f4'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f5'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f6'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f7'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f8'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3f9'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3fa'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3fb'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3fc'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3fd'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3fe'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee3ff'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('654fd7a56b7ce4b2632ee400'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee402'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee403'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee404'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee405'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee406'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee407'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee408'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee409'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee40a'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee40b'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee40c'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee40d'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee40e'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee40f'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee410'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee411'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee412'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee413'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee414'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('654fe3fe6b7ce4b2632ee415'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           654fbdb371ce47d4c8c66639
# name                      Vila Belmiro
# capacidade                       21732
# latitude                    -23.571243
# longitude                    -46.20123
# nome                               NaN
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[ center_lat, center_lon], zoom_start=5, width=800, height=600)

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 41

# %%
for i in range(qtde):
	lng = float(df_convertido.iloc[i]['longitude'])
	lat = float(df_convertido.iloc[i]['latitude'])
	description = 'Estádio: ' + str(df_convertido.iloc[i]['nome'])+ '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
	folium.Marker( [ lat , lng ],
                popup = description,
              	icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ae0b30e98bf8c4665cd2c19767f6a12 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ae0b30e98bf8c4665cd2c19767f6a12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ae0b30e98bf8c4665cd2c19767f6a12 = L.map(
#                 &quot;map_5ae0b30e98bf8c4665cd2c19767f6a12&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23fb4cab87af4f63633b554c24bb152a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ae0b30e98bf8c4665cd2c19767f6a12);
#
#
#             var marker_bf4b0d9ef06e6b53497f061e7dc55e4a = L.marker(
#                 [-23.571243, -46.20123],
#                 {}
#             ).addTo(map_5ae0b30e98bf8c4665cd2c19767f6a12);
#
#
#             var icon_2b7f4cf81552fa27b84ee33e0c6df083 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf4b0d9ef06e6b53497f061e7dc55e4a.setIcon(icon_2b7f4cf81552fa27b84ee33e0c6df083);
#
#
#         var popup_b4a6d18df25255cd8dccf05398429e1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_936dec063b787b06d757b32d6175fcc0 = $(`&lt;div id=&quot;html_936dec063b787b06d757b32d6175fcc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: nan&lt;br&gt; Capacidade: 21732&lt;/div&gt;`)[0];
#                 popup_b4a6d18df25255cd8dccf05398429e1b.setContent(html_936dec063b787b06d757b32d6175fcc0);
#
#
#
#         marker_bf4b0d9ef06e6b53497f061e7dc55e4a.bindPopup(popup_b4a6d18df25255cd8dccf05398429e1b)
#         ;
#
#
#
#
#             var marker_890c733d9a38ea12619b6fbe6b50dd99 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_5ae0b30e98bf8c4665cd2c19767f6a12);
#
#
#             var icon_5cda90615bc669a3c024a357b6e4d03c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_890c733d9a38ea12619b6fbe6b50dd99.setIcon(icon_5cda90615bc669a3c024a357b6e4d03c);
#
#
#         var popup_215ecf0e89d3e4ec0c27a4d79013c6fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35046fe31acbf44a6046377add95ad6a = $(`&lt;div id=&quot;html_35046fe31acbf44a6046377add95ad6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_215ecf0e89d3e4ec0c27a4d79013c6fa.setContent(html_35046fe31acbf44a6046377add95ad6a);
#
#
#
#         marker_890c733d9a38ea12619b6fbe6b50dd99.bindPopup(popup_215ecf0e89d3e4ec0c27a4d79013c6fa)
#         ;
#
#
#
#
#             var marker_2172cbe10179c90782d31fa80b7102fb = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_5ae0b30e98bf8c4665cd2c19767f6a12);
#
#
#             var icon_c6bee3f97a05e2cd0a1cd50852134e40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2172cbe10179c90782d31fa80b7102fb.setIcon(icon_c6bee3f97a05e2cd0a1cd50852134e40);
#
#
#         var popup_33280937b585532757f5f5b85ce6abcf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9e924b2d4f6888884ba6ae0cad46d13 = $(`&lt;div id=&quot;html_a9e924b2d4f6888884ba6ae0cad46d13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_33280937b585532757f5f5b85ce6abcf.setContent(html_a9e924b2d4f6888884ba6ae0cad46d13);
#
#
#
#         marker_2172cbe10179c90782d31fa80b7102fb.bindPopup(popup_33280937b585532757f5f5b85ce6abcf)
#         ;
#
#
#
#
#             var marker_b4b6a6915f9a6a0445e0a91c1d09e355 = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_5ae0b30e98bf8c4665cd2c19767f6a12);
#
#
#             var icon_d8a64de7a6efee3ec6dc87c69943597b = L.AwesomeMarkers.icon(
